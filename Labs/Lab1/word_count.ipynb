# %% [markdown]
# # Prerequisites

# %%
# get data for labs
# !wget -nc -O around_the_world_in_80_days.txt https://www.gutenberg.org/ebooks/103.txt.utf-8
# Out:
# File ‘around_the_world_in_80_days.txt’ already there; not retrieving.

# %% [markdown]
# # 1. Word Count

# %% [markdown]
# Instructions:
# For each cell marked "double-click and add explanation here" please answer the question in your own words.
# In the section where you complete the code to perform basic nlp text cleaning and exploration tasks, the goal is to chain all of the transformations together in a single function. For learning and exploration purposes, it is acceptable to have each step seperate, but the last cell in this section should be one function with all transformations chained together.
# For steps c and f, it is acceptable to use your favorite chatbot to generate a list of common stop words (c) and punctuation (e) for use in the code. As these are common steps in nlp/text processing tasks, there are pleanty of libraries to help with this such as nltk, but there is no need to import extra dependencies for this lab unless you are already familiar with working with them.

# %%
# start a spark session and create spark context for making rdd
from pyspark.sql import SparkSession
spark = SparkSession.builder \
    .appName("word_count") \
    .getOrCreate()

sc = spark.sparkContext

# %%
# Defind the rdd
rdd = sc.textFile('/home/jovyan/work/around_the_world_in_80_days.txt')

# %%
# view the first x lines of the rdd
rdd.take(20)
# Out:
# ['The Project Gutenberg eBook of Around the World in Eighty Days',
#  '    ',
#  'This eBook is for the use of anyone anywhere in the United States and',
#  'most other parts of the world at no cost and with almost no restrictions',
#  'whatsoever. You may copy it, give it away or re-use it under the terms',
#  'of the Project Gutenberg License included with this eBook or online',
#  'at www.gutenberg.org. If you are not located in the United States,',
#  'you will have to check the laws of the country where you are located',
#  'before using this eBook.',
#  '',
#  'Title: Around the World in Eighty Days',
#  '',
#  'Author: Jules Verne',
#  '',
#  'Translator: George M. Towle',
#  '',
#  '',
#  '        ',
#  'Release date: January 1, 1994 [eBook #103]',
#  '                Most recently updated: October 29, 2024']

# %%
# example lambda function
words = rdd.flatMap(lambda lines: lines.split(' '))

# %%
# Note and explain the output of the below command
words
# Out:
# PythonRDD[7] at RDD at PythonRDD.scala:59

# %% [markdown]
# Explanation :
# Here, Spark is first doing a transformation with flatMap but doesn't do anything immediately. Then when we call words alone, we are diplaying the refersence to the RDD object.

# %% [markdown]
# <ADD EXPLANATION HERE>

# %%
# Note and explain the output of the following command, focusing on the difference with the
# above command
words.collect()
# Out:
# ['The',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'of',
#  'Around',
#  'the',
#  'World',
#  'in',
#  'Eighty',
#  'Days',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'This',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'United',
#  'States',
#  'and',
#  'most',
#  'other',
#  'parts',
#  'of',
#  'the',
#  'world',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever.',
#  'You',
#  'may',
#  'copy',
#  'it,',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.org.',
#  'If',
#  'you',
#  'are',
#  'not',
#  'located',
#  'in',
#  'the',
#  'United',
#  'States,',
#  'you',
#  'will',
#  'have',
#  'to',
#  'check',
#  'the',
#  'laws',
#  'of',
#  'the',
# ...

# %% [markdown]
# Explanation :
# While words alone only returned a reference to the RDD object, .collect() trigged the actual execution of the transformation and collected the results as a concrete Python list. This is why we now see a list of actual words and spaces instead of an RDD object reference.

# %%
# nicer print
for w in words.collect():
    print(w)
# Out:
# ('The', 1)
# ('Project', 1)
# ('Gutenberg', 1)
# ('eBook', 1)
# ('of', 1)
# ('Around', 1)
# ('the', 1)
# ('World', 1)
# ('in', 1)
# ('Eighty', 1)
# ('Days', 1)
# ('', 1)
# ('', 1)
# ('', 1)
# ('', 1)
# ('', 1)
# ('This', 1)
# ('eBook', 1)
# ('is', 1)
# ('for', 1)
# ('the', 1)
# ('use', 1)
# ('of', 1)
# ('anyone', 1)
# ('anywhere', 1)
# ('in', 1)
# ('the', 1)
# ('United', 1)
# ('States', 1)
# ('and', 1)
# ('most', 1)
# ('other', 1)
# ('parts', 1)
# ('of', 1)
# ('the', 1)
# ('world', 1)
# ('at', 1)
# ('no', 1)
# ('cost', 1)
# ('and', 1)
# ('with', 1)
# ('almost', 1)
# ('no', 1)
# ('restrictions', 1)
# ('whatsoever.', 1)
# ('You', 1)
# ('may', 1)
# ('copy', 1)
# ('it,', 1)
# ('give', 1)
# ('it', 1)
# ('away', 1)
# ('or', 1)
# ('re-use', 1)
# ('it', 1)
# ('under', 1)
# ('the', 1)
# ('terms', 1)
# ('of', 1)
# ('the', 1)
# ('Project', 1)
# ('Gutenberg', 1)
# ('License', 1)
# ('included', 1)
# ('with', 1)
# ('this', 1)
# ('eBook', 1)
# ('or', 1)
# ('online', 1)
# ('at', 1)
# ...

# %%
# Print first x words
words.take(20)
# Out:
# [('The', 1),
#  ('Project', 1),
#  ('Gutenberg', 1),
#  ('eBook', 1),
#  ('of', 1),
#  ('Around', 1),
#  ('the', 1),
#  ('World', 1),
#  ('in', 1),
#  ('Eighty', 1),
#  ('Days', 1),
#  ('', 1),
#  ('', 1),
#  ('', 1),
#  ('', 1),
#  ('', 1),
#  ('This', 1),
#  ('eBook', 1),
#  ('is', 1),
#  ('for', 1)]

# %%
# Use cell magic command to help understand what the rdd.flatMap function is doing in the next cell.
# Insert a text/markdown cell and explain in your own words.

# %%
rdd.map(lambda lines: lines.split(' ')).take(3)
# Out:
# [['The',
#   'Project',
#   'Gutenberg',
#   'eBook',
#   'of',
#   'Around',
#   'the',
#   'World',
#   'in',
#   'Eighty',
#   'Days'],
#  ['', '', '', '', ''],
#  ['This',
#   'eBook',
#   'is',
#   'for',
#   'the',
#   'use',
#   'of',
#   'anyone',
#   'anywhere',
#   'in',
#   'the',
#   'United',
#   'States',
#   'and']]

# %%
rdd.flatMap(lambda lines: lines.split(' ')).take(3)
# Out:
# ['The', 'Project', 'Gutenberg']

# %% [markdown]
# Explication :
# To understand how flatMap works, I compared it to the map function. we can see a real difference between the two outputs : one is lists in a list and the otherone is a simple list of words. we can understant that flatMap actually flatten our text as if it was one long line.

# %%
# Initialize a word counter by creating a tuple with word and cound of 1
words = rdd.flatMap(lambda lines: lines.split(' ')) \
                    .map(lambda word: (word, 1))

for w in words.collect():
    print(w)
# Out:
# ('The', 1)
# ('Project', 1)
# ('Gutenberg', 1)
# ('eBook', 1)
# ('of', 1)
# ('Around', 1)
# ('the', 1)
# ('World', 1)
# ('in', 1)
# ('Eighty', 1)
# ('Days', 1)
# ('', 1)
# ('', 1)
# ('', 1)
# ('', 1)
# ('', 1)
# ('This', 1)
# ('eBook', 1)
# ('is', 1)
# ('for', 1)
# ('the', 1)
# ('use', 1)
# ('of', 1)
# ('anyone', 1)
# ('anywhere', 1)
# ('in', 1)
# ('the', 1)
# ('United', 1)
# ('States', 1)
# ('and', 1)
# ('most', 1)
# ('other', 1)
# ('parts', 1)
# ('of', 1)
# ('the', 1)
# ('world', 1)
# ('at', 1)
# ('no', 1)
# ('cost', 1)
# ('and', 1)
# ('with', 1)
# ('almost', 1)
# ('no', 1)
# ('restrictions', 1)
# ('whatsoever.', 1)
# ('You', 1)
# ('may', 1)
# ('copy', 1)
# ('it,', 1)
# ('give', 1)
# ('it', 1)
# ('away', 1)
# ('or', 1)
# ('re-use', 1)
# ('it', 1)
# ('under', 1)
# ('the', 1)
# ('terms', 1)
# ('of', 1)
# ('the', 1)
# ('Project', 1)
# ('Gutenberg', 1)
# ('License', 1)
# ('included', 1)
# ('with', 1)
# ('this', 1)
# ('eBook', 1)
# ('or', 1)
# ('online', 1)
# ('at', 1)
# ...

# %%
# a. count the occurence of each word
occurrences = rdd.flatMap(lambda lines: lines.split(' ')) \
                    .map(lambda word: (word, 1)) \
                    .reduceByKey(lambda a, b: a + b)

occurrences.collect()
# Out:
# [('Gutenberg', 60),
#  ('eBook', 6),
#  ('of', 1875),
#  ('Around', 4),
#  ('', 2193),
#  ('for', 407),
#  ('use', 16),
#  ('anyone', 6),
#  ('United', 23),
#  ('States', 10),
#  ('and', 1793),
#  ('most', 43),
#  ('other', 59),
#  ('world', 30),
#  ('at', 576),
#  ('no', 124),
#  ('cost', 9),
#  ('with', 550),
#  ('almost', 19),
#  ('restrictions', 2),
#  ('give', 17),
#  ('it', 322),
#  ('re-use', 2),
#  ('under', 41),
#  ('License', 8),
#  ('this', 292),
#  ('online', 4),
#  ('www.gutenberg.org.', 4),
#  ('If', 31),
#  ('you', 243),
#  ('are', 169),
#  ('States,', 6),
#  ('will', 108),
#  ('have', 259),
#  ('to', 1690),
#  ('country', 18),
#  ('where', 65),
#  ('before', 77),
#  ('using', 6),
#  ('Author:', 1),
#  ('Translator:', 1),
#  ('date:', 1),
#  ('1,', 1),
#  ('[eBook', 1),
#  ('#103]', 1),
#  ('October', 11),
#  ('29,', 1),
#  ('information', 4),
#  ('formats:', 1),
#  ('www.gutenberg.org/ebooks/103', 1),
#  ('***', 4),
#  ('START', 1),
#  ('PROJECT', 4),
# ...

# %%
# b. a common first step in text analysis, change all capital letters to lower case
count = rdd.flatMap(lambda lines: lines.split(' ')) \
                    .map(lambda word: word.lower()) \
                    .map(lambda word: (word, 1)) \
                    .reduceByKey(lambda a, b: a + b)

count.collect()
# Out:
# [('of', 1926),
#  ('around', 32),
#  ('world', 35),
#  ('eighty', 27),
#  ('days', 46),
#  ('', 2193),
#  ('this', 341),
#  ('for', 414),
#  ('use', 19),
#  ('anyone', 6),
#  ('united', 27),
#  ('states', 14),
#  ('and', 1835),
#  ('most', 45),
#  ('other', 63),
#  ('at', 645),
#  ('no', 137),
#  ('cost', 12),
#  ('with', 562),
#  ('almost', 19),
#  ('restrictions', 2),
#  ('you', 280),
#  ('give', 18),
#  ('it', 471),
#  ('re-use', 2),
#  ('under', 44),
#  ('license', 12),
#  ('online', 4),
#  ('www.gutenberg.org.', 4),
#  ('are', 175),
#  ('states,', 7),
#  ('will', 111),
#  ('have', 267),
#  ('to', 1735),
#  ('country', 18),
#  ('where', 69),
#  ('before', 81),
#  ('using', 6),
#  ('ebook.', 2),
#  ('title:', 1),
#  ('jules', 2),
#  ('verne', 2),
#  ('translator:', 1),
#  ('m.', 2),
#  ('towle', 1),
#  ('release', 2),
#  ('date:', 1),
#  ('january', 1),
#  ('1,', 1),
#  ('#103]', 1),
#  ('29,', 1),
#  ('language:', 1),
#  ('information', 8),
#  ('formats:', 1),
# ...

# %%
# c. eliminate the stop words.
stop_words = set(['the', 'a', 'an', 'of', 'in', 'it', 'to', 'and', 'or', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'for', 'on', 'with', 'as', 'by', 'at', 'from'])

count = rdd.flatMap(lambda lines: lines.split(' ')) \
                    .map(lambda word: word.lower()) \
                    .filter(lambda word: word not in stop_words) \
                    .map(lambda word: (word, 1)) \
                    .reduceByKey(lambda a, b: a + b)

count.collect()
# Out:
# [('around', 32),
#  ('world', 35),
#  ('eighty', 27),
#  ('days', 46),
#  ('', 2193),
#  ('this', 341),
#  ('use', 19),
#  ('anyone', 6),
#  ('united', 27),
#  ('states', 14),
#  ('most', 45),
#  ('other', 63),
#  ('no', 137),
#  ('cost', 12),
#  ('almost', 19),
#  ('restrictions', 2),
#  ('you', 280),
#  ('give', 18),
#  ('it', 471),
#  ('re-use', 2),
#  ('under', 44),
#  ('license', 12),
#  ('online', 4),
#  ('www.gutenberg.org.', 4),
#  ('states,', 7),
#  ('will', 111),
#  ('have', 267),
#  ('country', 18),
#  ('where', 69),
#  ('before', 81),
#  ('using', 6),
#  ('ebook.', 2),
#  ('title:', 1),
#  ('jules', 2),
#  ('verne', 2),
#  ('translator:', 1),
#  ('m.', 2),
#  ('towle', 1),
#  ('release', 2),
#  ('date:', 1),
#  ('january', 1),
#  ('1,', 1),
#  ('#103]', 1),
#  ('29,', 1),
#  ('language:', 1),
#  ('information', 8),
#  ('formats:', 1),
#  ('www.gutenberg.org/ebooks/103', 1),
#  ('***', 4),
#  ('start', 9),
#  ('[illustration]', 1),
#  ('contents', 1),
#  ('chapter', 74),
# ...

# %%
# d. sort in alphabetical order
sorted_words = rdd.flatMap(lambda lines: lines.split(' ')) \
                    .map(lambda word: word.lower()) \
                    .map(lambda word: (word, 1)) \
                    .reduceByKey(lambda a, b: a + b) \
                    .sortByKey()

sorted_words.collect()
# Out:
# [('', 2193),
#  ('#103]', 1),
#  ('#516,', 1),
#  ('$5,000)', 1),
#  ('&c.,', 1),
#  ('($1', 1),
#  ('(862)', 1),
#  ('(a)', 1),
#  ('(and', 1),
#  ('(any', 1),
#  ('(b)', 1),
#  ('(c)', 1),
#  ('(does', 1),
#  ('(if', 1),
#  ('(japan),', 1),
#  ('(or', 3),
#  ('(saturday,', 1),
#  ('(sort', 1),
#  ('(sunday)', 1),
#  ('(trademark/copyright)', 1),
#  ('(www.gutenberg.org),', 1),
#  ('(“the', 1),
#  ('***', 4),
#  ('+1', 1),
#  ('-', 3),
#  ('-------', 1),
#  ('.', 3),
#  ('.....', 1),
#  ('........', 1),
#  ('.........', 1),
#  ('.............', 2),
#  ('.................', 1),
#  ('...................', 1),
#  ('....................', 1),
#  ('............................................', 1),
#  ('07042,', 1),
#  ('1,', 1),
#  ('1,000.', 1),
#  ('1,170,', 1),
#  ('1.', 1),
#  ('1.a.', 1),
#  ('1.b.', 1),
#  ('1.c', 1),
#  ('1.c.', 1),
#  ('1.d.', 1),
#  ('1.e', 1),
#  ('1.e.', 1),
#  ('1.e.1', 3),
#  ('1.e.1.', 2),
#  ('1.e.2.', 1),
#  ('1.e.3.', 1),
#  ('1.e.4.', 1),
# ...

# %%
# e. sort descending by word frequency
sorted_words_desc = rdd.flatMap(lambda lines: lines.split(' ')) \
                    .map(lambda word: (word, 1)) \
                    .reduceByKey(lambda a, b: a + b) \
                    .sortBy(lambda x: x[1], ascending=False)

sorted_words_desc.collect()
# Out:
# [('the', 4316),
#  ('', 2193),
#  ('of', 1875),
#  ('and', 1793),
#  ('to', 1690),
#  ('a', 1261),
#  ('in', 991),
#  ('was', 974),
#  ('his', 804),
#  ('he', 720),
#  ('at', 576),
#  ('with', 550),
#  ('not', 500),
#  ('had', 484),
#  ('The', 482),
#  ('on', 482),
#  ('that', 460),
#  ('which', 414),
#  ('for', 407),
#  ('as', 396),
#  ('by', 377),
#  ('Mr.', 371),
#  ('Fogg', 331),
#  ('it', 322),
#  ('be', 307),
#  ('from', 302),
#  ('were', 300),
#  ('this', 292),
#  ('is', 288),
#  ('would', 266),
#  ('have', 259),
#  ('you', 243),
#  ('an', 222),
#  ('Passepartout', 219),
#  ('but', 216),
#  ('Phileas', 214),
#  ('He', 208),
#  ('I', 207),
#  ('or', 185),
#  ('they', 183),
#  ('him', 181),
#  ('who', 179),
#  ('are', 169),
#  ('been', 167),
#  ('said', 155),
#  ('her', 146),
#  ('their', 145),
#  ('It', 139),
#  ('if', 138),
#  ('could', 136),
#  ('its', 133),
#  ('all', 131),
#  ('Fogg,', 130),
#  ('one', 125),
#  ('no', 124),
#  ('Fix', 122),
#  ('did', 119),
# ...

# %%
# f. remove punctuations and blank spaces
clean = rdd.flatMap(lambda lines: lines.split(' ')) \
                    .map(lambda word: word.strip('.,!:;?()[]{}"\'-_`/')) \
                    .filter(lambda word: word != '')

clean.collect()
# Out:
# ['The',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'Around',
#  'World',
#  'Eighty',
#  'Days',
#  'This',
#  'eBook',
#  'use',
#  'anyone',
#  'anywhere',
#  'United',
#  'States',
#  'most',
#  'other',
#  'parts',
#  'world',
#  'no',
#  'cost',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever.',
#  'You',
#  'may',
#  'copy',
#  'it,',
#  'give',
#  'it',
#  'away',
#  're-use',
#  'it',
#  'under',
#  'terms',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'this',
#  'eBook',
#  'online',
#  'www.gutenberg.org.',
#  'If',
#  'you',
#  'not',
#  'located',
#  'United',
#  'States,',
#  'you',
#  'will',
#  'have',
#  'check',
#  'laws',
#  'country',
#  'where',
#  'you',
#  'located',
#  'before',
#  'using',
#  'this',
#  'eBook.',
#  'Title:',
#  'Around',
#  'World',
#  'Eighty',
#  'Days',
#  'Author:',
#  'Jules',
#  'Verne',
#  'Translator:',
#  'George',
#  'M.',
#  'Towle',
#  'Release',
#  'date:',
#  'January',
#  '1,',
#  '1994',
# ...

# %%
def get_clean_word_count(rdd):
    stop_words = set(['the', 'a', 'an', 'of', 'in', 'it', 'to', 'and', 'or', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'for', 'on', 'with', 'as', 'by', 'at', 'from'])

    clean = rdd.flatMap(lambda lines: lines.split(' ')) \
                    .map(lambda word: word.lower()) \
                    .map(lambda word: word.strip('.,!:;?()[]{}"\'-_`/')) \
                    .filter(lambda word: word != '' and word not in stop_words) \
                    .map(lambda word: (word, 1)) \
                    .reduceByKey(lambda a, b: a + b) \
                    .sortBy(lambda x: x[1], ascending=False)

    return clean

get_clean_word_count(rdd).take(20)
# Out:
# [('he', 966),
#  ('his', 857),
#  ('fogg', 577),
#  ('not', 535),
#  ('which', 515),
#  ('had', 513),
#  ('that', 508),
#  ('passepartout', 392),
#  ('mr', 373),
#  ('this', 347),
#  ('but', 326),
#  ('you', 315),
#  ('him', 314),
#  ('would', 278),
#  ('have', 270),
#  ('phileas', 250),
#  ('they', 232),
#  ('fix', 228),
#  ('i', 213),
#  ('who', 199)]

# %% [markdown]
# # 2. What does the following cell block do?
# Comment the code below line by line after the provided hash-tag. You should be able to explain each line while respecting the pep8 style guide of 79 characters or less per line!

# %%
 # Create an RDD of tuples (name, age)
dataRDD = sc.parallelize([("Brooke", 20), ("Denny", 31), ("Jules", 30),
("TD", 35), ("Brooke", 25)])

# Try to undestand what this code does (line by line)
agesRDD = (dataRDD
  # creates a list of tuple composed of a key (the name) and a tuple (age, 1) 
  # it enables later on to count the number of occurences of a name just by 
  # doing the sum of the 1 at the end
  .map(lambda x: (x[0], (x[1], 1)))
  # sums up the age and the count of occurrence of the name, 
  # grouping by the key, here the names
  .reduceByKey(lambda x, y: (x[0] + y[0], x[1] + y[1]))
  # calculates the mean of the age by deviding the sum of the age by the count 
  # of occurrences of the name in the list and it reduce the tuple composed of 
  # a key and a tuple to a tuple composed of a key and an int
  .map(lambda x: (x[0], x[1][0]/x[1][1])))

agesRDD.take(20)
# Out:
# [('Denny', 31.0), ('TD', 35.0), ('Jules', 30.0), ('Brooke', 22.5)]

# %% [markdown]
# ## 3. Function timing.
#
# - write a simple python timer function for seeing how quickly your rdd runs as written. change the order of the steps in order to make the rdd run as optimally as possible

# %%
# Code here
import time

def timer(func, rdd):
    start = time.time()
    function = func(rdd)
    function.collect()
    end = time.time()
    execution_time = end - start

    return execution_time

def get_clean_word_count_optimized(rdd):
    stop_words = set(['the', 'a', 'an', 'of', 'in', 'it', 'to', 'and', 
                      'or', 'is', 'are', 'was', 'were', 'be', 'been', 
                      'being', 'for', 'on', 'with', 'as', 'by', 'at', 'from'])
    
    clean = rdd.flatMap(lambda lines: lines.split(' ')) \
                    .filter(lambda word: word != '') \
                    .map(lambda word: word.lower()) \
                    .map(lambda word: word.strip('.,!:;?()[]{}"\'-_`/')) \
                    .filter(lambda word: word not in stop_words) \
                    .map(lambda word: (word, 1)) \
                    .reduceByKey(lambda a, b: a + b) \
                    .sortBy(lambda x: x[1], ascending=False)

    return clean

execution_time_1 = timer(get_clean_word_count, rdd)
execution_time_2 = timer(get_clean_word_count_optimized, rdd)

print(f"Execution time: {execution_time_1} seconds")
print(f"Execution time: {execution_time_2} seconds")
# Out:
# Execution time: 0.5904381275177002 seconds
# Execution time: 0.3426492214202881 seconds

# %% [markdown]
# ## 4. Text Comparison
#
# - perform eda on the original french version of the [book](https://www.gutenberg.org/ebooks/46541.txt.utf-8) and compare the two

# %%
# Get the french version of the book
# !wget -nc -O around_the_world_in_80_days_french.txt https://www.gutenberg.org/cache/epub/46541/pg46541.txt
# Out:
# --2026-09-17 14:11:50--  https://www.gutenberg.org/cache/epub/46541/pg46541.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47, ...
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 472731 (462K) [text/plain]
# Saving to: ‘around_the_world_in_80_days_french.txt’
#
# around_the_world_in 100%[===================>] 461.65K   746KB/s    in 0.6s
#
# 2026-09-17 14:11:52 (746 KB/s) - ‘around_the_world_in_80_days_french.txt’ saved [472731/472731]

# %%
# start a spark session and create spark context for making french_rdd
from pyspark.sql import SparkSession
spark = SparkSession.builder \
    .appName("word_count") \
    .getOrCreate()

sc = spark.sparkContext

# %%
# Define the french_rdd
french_rdd = sc.textFile('/home/jovyan/work/around_the_world_in_80_days_french.txt')

# %%
french_rdd.collect()

# %%
def french_get_clean_word_count_optimized(rdd):
    stop_words = set(['le', 'la', 'les', 'l', 'du', 'de', 'des', 'un', 'une', 
                      'vous', 'tu', 'je', 'il', 'elle', 'nous', 'vous', 'ils', 
                      'elles', 'ce', 'cette', 'ces', 'mon', 'ma', 'mes', 'ton', 
                      'ta', 'tes', 'son', 'sa', 'ses', 'notre', 'nos', 'votre', 
                      'vos', 'leur', 'leurs', 'et', 'ou', 'est', 'sont', 'était', 
                      'étaient', 'être', 'été', 'étant', 'pour', 'sur', 'avec', 
                      'comme', 'par', 'à', 'de', 'le', 'la', 'les', 'l', 'du', 
                      'de', 'au', 'des', 'un', 'une', 'en', 'que', 'qui', 'quoi', 
                      'dont', 'où', 'quand', 'comment', 'combien', 'dans', 'lui', 
                      'elle', 'eux', 'elles', 'moi', 'toi', 'nous', 'vous', 'leur',])
    
    clean = rdd.flatMap(lambda lines: lines.split(' ')) \
                    .filter(lambda word: word != '') \
                    .map(lambda word: word.lower()) \
                    .map(lambda word: word.strip('.,!:;?()[]{}"\'-_`/')) \
                    .filter(lambda word: word not in stop_words) \
                    .map(lambda word: (word, 1)) \
                    .reduceByKey(lambda a, b: a + b) \
                    .sortBy(lambda x: x[1], ascending=False)

    return clean

# %%
clean_french_word_count = french_get_clean_word_count_optimized(french_rdd)
clean_french_word_count.collect()
# Out:
# [('fogg', 681),
#  ('se', 592),
#  ('ne', 565),
#  ('pas', 472),
#  ('passepartout', 449),
#  ('mais', 360),
#  ('plus', 337),
#  ('phileas', 328),
#  ('mr', 287),
#  ('fix', 284),
#  ('avait', 280),
#  ('a', 258),
#  ('heures', 242),
#  ('on', 234),
#  ('répondit', 215),
#  ("qu'il", 194),
#  ('tout', 192),
#  ('the', 188),
#  ('bien', 181),
#  ('si', 181),
#  ('sans', 164),
#  ('deux', 145),
#  ('dit', 138),
#  ('aouda', 132),
#  ("d'un", 131),
#  ('mrs', 131),
#  ('quelques', 129),
#  ('après', 124),
#  ('of', 123),
#  ('même', 121),
#  ("c'était", 118),
#  ('maître', 116),
#  ('fut', 113),
#  ('train', 112),
#  ('donc', 112),
#  ('ni', 109),
#  ('aux', 109),
#  ('or', 107),
#  ("d'une", 106),
#  ('mille', 104),
#  ('monsieur', 103),
#  ('y', 103),
#  ('encore', 100),
#  ('temps', 100),
#  ('jours', 99),
#  ('pendant', 96),
#  ('peu', 92),
#  ('avoir', 89),
#  ('eût', 88),
#  ('faire', 88),
#  ("c'est", 87),
#  ('vers', 86),
#  ('gentleman', 85),
#  ('to', 83),
# ...
